# %% [markdown]
# # Livros - csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/livros.csv')
df.head()
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# 4         Family saga

# %%
df.shape
# Out:
# (174, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Book                           174 non-null    object
#  1   Author(s)                      174 non-null    object
#  2   Original language              174 non-null    object
#  3   First published                174 non-null    int64
#  4   Approximate sales in millions  174 non-null    float64
#  5   Genre                          118 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 8.3+ KB

# %%
df.columns
# Out:
# Index(['Book', 'Author(s)', 'Original language', 'First published',
#        'Approximate sales in millions', 'Genre'],
#       dtype='object')

# %%
# renomear as colunas para o portugues
traducao = {
    'Book':'livro',
    'Author(s)':'autor',
    'Original language':'idioma_original',
    'First published':'ano_publicacao',
    'Approximate sales in millions':'vendas',
    'Genre':'genero'
}

df.rename(columns=traducao, inplace=True)
df.head()
# Out:
#                                       livro                     autor  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   idioma_original  ano_publicacao  vendas              genero
# 0         English            1859   200.0  Historical fiction
# 1          French            1943   200.0             Novella
# 2         English            1997   120.0             Fantasy
# 3         English            1939   100.0             Mystery
# 4         Chinese            1791   100.0         Family saga

# %%
# dados nulos
df.isnull().sum()
# Out:
# livro               0
# autor               0
# idioma_original     0
# ano_publicacao      0
# vendas              0
# genero             56
# dtype: int64

# %%
df['autor'].value_counts().head(10)
# Out:
# autor
# J. K. Rowling       7
# Dan Brown           3
# Suzanne Collins     3
# Roald Dahl          3
# George Orwell       2
# Ken Follett         2
# E. L. James         2
# Albert Camus        2
# Erskine Caldwell    2
# Cao Xueqin          1
# Name: count, dtype: int64

# %%
df[df['autor'] == 'J. K. Rowling']
# Out:
#                                         livro          autor idioma_original  \
# 2    Harry Potter and the Philosopher's Stone  J. K. Rowling         English
# 10    Harry Potter and the Chamber of Secrets  J. K. Rowling         English
# 11   Harry Potter and the Prisoner of Azkaban  J. K. Rowling         English
# 12        Harry Potter and the Goblet of Fire  J. K. Rowling         English
# 13  Harry Potter and the Order of the Phoenix  J. K. Rowling         English
# 14     Harry Potter and the Half-Blood Prince  J. K. Rowling         English
# 15       Harry Potter and the Deathly Hallows  J. K. Rowling         English
#
#     ano_publicacao  vendas   genero
# 2             1997   120.0  Fantasy
# 10            1998    77.0  Fantasy
# 11            1999    65.0  Fantasy
# 12            2000    65.0  Fantasy
# 13            2003    65.0  Fantasy
# 14            2005    65.0  Fantasy
# 15            2007    65.0  Fantasy

# %%
# Cria um novo DataFrame apenas com os autores únicos encontrados na coluna 'autor' do DataFrame original (df)
# .unique() retorna uma lista com cada autor aparecendo apenas uma vez
# Isso é necessário para que possamos gerar um único ID para cada autor
autores_unicos = pd.DataFrame(df['autor'].unique(), columns=['autor'])

# Cria uma nova coluna chamada 'autor_id' no DataFrame de autores únicos
# Atribui um ID numérico sequencial a cada autor, começando de 1
# Isso garante que cada autor tenha um identificador exclusivo e consistente
autores_unicos['autor_id'] = autores_unicos.index + 1

# Faz um merge (junção) entre o DataFrame original (df) e o DataFrame de autores únicos (autores_unicos)
# A junção é feita com base na coluna 'autor' (chave de correspondência)
# O tipo de junção é 'left', o que significa que todas as linhas do df original são mantidas
# e os IDs correspondentes dos autores são adicionados na nova coluna 'autor_id'
df = df.merge(autores_unicos, on='autor', how='left')

# Isso serve para verificar se a coluna 'autor_id' foi corretamente adicionada e associada
df.head()
# Out:
#                                       livro                     autor  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   idioma_original  ano_publicacao  vendas              genero  autor_id
# 0         English            1859   200.0  Historical fiction         1
# 1          French            1943   200.0             Novella         2
# 2         English            1997   120.0             Fantasy         3
# 3         English            1939   100.0             Mystery         4
# 4         Chinese            1791   100.0         Family saga         5

# %%
df[df['autor'] == 'J. K. Rowling']
# Out:
#                                         livro          autor idioma_original  \
# 2    Harry Potter and the Philosopher's Stone  J. K. Rowling         English
# 10    Harry Potter and the Chamber of Secrets  J. K. Rowling         English
# 11   Harry Potter and the Prisoner of Azkaban  J. K. Rowling         English
# 12        Harry Potter and the Goblet of Fire  J. K. Rowling         English
# 13  Harry Potter and the Order of the Phoenix  J. K. Rowling         English
# 14     Harry Potter and the Half-Blood Prince  J. K. Rowling         English
# 15       Harry Potter and the Deathly Hallows  J. K. Rowling         English
#
#     ano_publicacao  vendas   genero  autor_id
# 2             1997   120.0  Fantasy         3
# 10            1998    77.0  Fantasy         3
# 11            1999    65.0  Fantasy         3
# 12            2000    65.0  Fantasy         3
# 13            2003    65.0  Fantasy         3
# 14            2005    65.0  Fantasy         3
# 15            2007    65.0  Fantasy         3

# %%
generos_unicos = pd.DataFrame(df['genero'].unique(), columns=['genero'])
generos_unicos['genero_id'] = generos_unicos.index + 1
df = df.merge(generos_unicos, on='genero', how='left')
df.head()
# Out:
#                                       livro                     autor  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   idioma_original  ano_publicacao  vendas              genero  autor_id  \
# 0         English            1859   200.0  Historical fiction         1
# 1          French            1943   200.0             Novella         2
# 2         English            1997   120.0             Fantasy         3
# 3         English            1939   100.0             Mystery         4
# 4         Chinese            1791   100.0         Family saga         5
#
#    genero_id
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
df[df['autor'] == 'J. K. Rowling']
# Out:
#                                         livro          autor idioma_original  \
# 2    Harry Potter and the Philosopher's Stone  J. K. Rowling         English
# 10    Harry Potter and the Chamber of Secrets  J. K. Rowling         English
# 11   Harry Potter and the Prisoner of Azkaban  J. K. Rowling         English
# 12        Harry Potter and the Goblet of Fire  J. K. Rowling         English
# 13  Harry Potter and the Order of the Phoenix  J. K. Rowling         English
# 14     Harry Potter and the Half-Blood Prince  J. K. Rowling         English
# 15       Harry Potter and the Deathly Hallows  J. K. Rowling         English
#
#     ano_publicacao  vendas   genero  autor_id  genero_id
# 2             1997   120.0  Fantasy         3          3
# 10            1998    77.0  Fantasy         3          3
# 11            1999    65.0  Fantasy         3          3
# 12            2000    65.0  Fantasy         3          3
# 13            2003    65.0  Fantasy         3          3
# 14            2005    65.0  Fantasy         3          3
# 15            2007    65.0  Fantasy         3          3

# %%
autores = pd.DataFrame(df['autor'].unique(), columns=['nome'])
generos = pd.DataFrame(df['genero'].unique(), columns=['genero'])

# %%
with open('autores.sql', 'w', encoding='utf-8') as f:
  for _, row in autores.iterrows():
        nome = row['nome'].replace("'", "''")  # aspas simples para SQL
        f.write(f"INSERT INTO autores (nome) VALUES ('{nome}');\n")

# %%
df['genero'] = df['genero'].fillna('Unknown')
df.head(20)
# Out:
#                                         livro                     autor  \
# 0                        A Tale of Two Cities           Charles Dickens
# 1         The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2    Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                    And Then There Were None           Agatha Christie
# 4              Dream of the Red Chamber (紅樓夢)                Cao Xueqin
# 5                                  The Hobbit          J. R. R. Tolkien
# 6        The Lion, the Witch and the Wardrobe               C. S. Lewis
# 7                 She: A History of Adventure          H. Rider Haggard
# 8         Vardi Wala Gunda (वर्दी वाला गुंडा)        Ved Prakash Sharma
# 9                           The Da Vinci Code                 Dan Brown
# 10    Harry Potter and the Chamber of Secrets             J. K. Rowling
# 11   Harry Potter and the Prisoner of Azkaban             J. K. Rowling
# 12        Harry Potter and the Goblet of Fire             J. K. Rowling
# 13  Harry Potter and the Order of the Phoenix             J. K. Rowling
# 14     Harry Potter and the Half-Blood Prince             J. K. Rowling
# 15       Harry Potter and the Deathly Hallows             J. K. Rowling
# 16               The Alchemist (O Alquimista)              Paulo Coelho
# 17                     The Catcher in the Rye            J. D. Salinger
# 18              The Bridges of Madison County       Robert James Waller
# 19              Ben-Hur: A Tale of the Christ               Lew Wallace
#
#    idioma_original  ano_publicacao  vendas                       genero  \
# 0          English            1859   200.0           Historical fiction
# 1           French            1943   200.0                      Novella
# 2          English            1997   120.0                      Fantasy
# 3          English            1939   100.0                      Mystery
# 4          Chinese            1791   100.0                  Family saga
# 5          English            1937   100.0                      Fantasy
# 6          English            1950    85.0  Fantasy, Children's fiction
# 7          English            1887    83.0                    Adventure
# 8            Hindi            1992    80.0                    Detective
# 9          English            2003    80.0             Mystery thriller
# 10         English            1998    77.0                      Fantasy
# 11         English            1999    65.0                      Fantasy
# 12         English            2000    65.0                      Fantasy
# 13         English            2003    65.0                      Fantasy
# 14         English            2005    65.0                      Fantasy
# 15         English            2007    65.0                      Fantasy
# 16      Portuguese            1988    65.0                      Fantasy
# 17         English            1951    65.0                Coming-of-age
# 18         English            1992    60.0                      Romance
# 19         English            1880    50.0           Historical fiction
#
#     autor_id  genero_id
# 0          1          1
# 1          2          2
# 2          3          3
# 3          4          4
# 4          5          5
# 5          6          3
# 6          7          6
# 7          8          7
# 8          9          8
# 9         10          9
# 10         3          3
# 11         3          3
# 12         3          3
# 13         3          3
# 14         3          3
# 15         3          3
# 16        11          3
# 17        12         10
# 18        13         11
# 19        14          1

# %%
df['genero'].isnull().sum()
# Out:
# np.int64(0)

# %%
generos = pd.DataFrame(df['genero'].unique(), columns=['genero'])
generos
# Out:
#                            genero
# 0              Historical fiction
# 1                         Novella
# 2                         Fantasy
# 3                         Mystery
# 4                     Family saga
# ..                            ...
# 76  Historical fiction, war novel
# 77                        Erotica
# 78                Science fiction
# 79              Dystopian fiction
# 80                         Horror
#
# [81 rows x 1 columns]

# %%
# !pip install -q deep-translator

from deep_translator import GoogleTranslator

# Supondo que você tenha um DataFrame chamado generos com a coluna 'genero'
generos['genero_pt'] = generos['genero'].apply(
    lambda x: GoogleTranslator(source='auto', target='pt').translate(x)
)

generos.head()
# Out:
#                genero         genero_pt
# 0  Historical fiction  Ficção histórica
# 1             Novella           Novella
# 2             Fantasy          Fantasia
# 3             Mystery          Mistério
# 4         Family saga   Saga da família

# %%
generos['genero_pt'] = generos['genero_pt'].replace('Novella', 'Novela')
generos.head()
# Out:
#                genero         genero_pt
# 0  Historical fiction  Ficção histórica
# 1             Novella            Novela
# 2             Fantasy          Fantasia
# 3             Mystery          Mistério
# 4         Family saga   Saga da família

# %%
generos['genero_pt'] = generos['genero_pt'].str.lower()
generos.head()
# Out:
#                genero         genero_pt
# 0  Historical fiction  ficção histórica
# 1             Novella            novela
# 2             Fantasy          fantasia
# 3             Mystery          mistério
# 4         Family saga   saga da família

# %%
generos.shape
# Out:
# (81, 2)

# %%
with open('generos.sql', 'w', encoding='utf-8') as f:
    for nome in generos['genero_pt']:
        nome_escapado = nome.replace("'", "''")  # aspas simples para SQL
        f.write(f"INSERT INTO generos (nome) VALUES ('{nome_escapado}');\n")

# %%
with open('livros.sql', 'w', encoding='utf-8') as f:
    for _, row in df.iterrows():
        nome_livro = row['livro'].replace("'", "''")  # Escapa aspas simples
        idioma = row['idioma_original'].replace("'", "''")
        ano = int(row['ano_publicacao'])
        vendas = float(row['vendas'])
        autor_id = int(row['autor_id'])
        genero_id = int(row['genero_id'])

        sql = (
            f"INSERT INTO livros (nome, idioma, ano_publicacao, vendas, autor_id, genero_id) "
            f"VALUES ('{nome_livro}', '{idioma}', {ano}, {vendas:.2f}, {autor_id}, {genero_id});\n"
        )
        f.write(sql)

# %% [markdown]
# # Lojas - API

# %%
# https://raw.githubusercontent.com/guilhermeonrails/datas-csv/refs/heads/main/comentarios.json

# %%
import pandas as pd

api = 'https://raw.githubusercontent.com/guilhermeonrails/datas-csv/refs/heads/main/comentarios.json'
df_comentarios = pd.read_json(api)
df_comentarios.head()
# Out:
#    id                                 livro      nome sobrenome  \
# 0   1                        The Dukan Diet  Danielle   Johnson
# 1   2  The Lion, the Witch and the Wardrobe    Joshua    Walker
# 2   3             James and the Giant Peach      Jill    Rhodes
# 3   4           The Very Hungry Caterpillar  Patricia    Miller
# 4   5                 Bridget Jones's Diary    Robert   Johnson
#
#                                       comentario
# 0     Achei a história envolvente e bem escrita.
# 1                       Esperava mais do enredo.
# 2  Personagens cativantes e trama surpreendente.
# 3     Achei a história envolvente e bem escrita.
# 4                     Um dos melhores que já li.

# %%
df_comentarios.shape
# Out:
# (10000, 5)

# %%
df.head(2)
# Out:
#                                  livro                     autor  \
# 0                 A Tale of Two Cities           Charles Dickens
# 1  The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
#
#   idioma_original  ano_publicacao  vendas              genero  autor_id  \
# 0         English            1859   200.0  Historical fiction         1
# 1          French            1943   200.0             Novella         2
#
#    genero_id
# 0          1
# 1          2

# %%
df_comentarios = df_comentarios.merge(
    df[['livro']].reset_index().rename(columns={'index': 'id_livro'}),
    on='livro',
    how='left'
)
df_comentarios.head()
# Out:
#    id                                 livro      nome sobrenome  \
# 0   1                        The Dukan Diet  Danielle   Johnson
# 1   2  The Lion, the Witch and the Wardrobe    Joshua    Walker
# 2   3             James and the Giant Peach      Jill    Rhodes
# 3   4           The Very Hungry Caterpillar  Patricia    Miller
# 4   5                 Bridget Jones's Diary    Robert   Johnson
#
#                                       comentario  id_livro
# 0     Achei a história envolvente e bem escrita.       163
# 1                       Esperava mais do enredo.         6
# 2  Personagens cativantes e trama surpreendente.        62
# 3     Achei a história envolvente e bem escrita.        35
# 4                     Um dos melhores que já li.       173

# %%
df_comentarios.isnull().sum()
# Out:
# id            0
# livro         0
# nome          0
# sobrenome     0
# comentario    0
# id_livro      0
# dtype: int64

# %%
print(f"{df_comentarios['id_livro'].max()} {df_comentarios['id_livro'].min()}")
# Out:
# 173 0

# %%
df_comentarios[df_comentarios['id_livro'] == 0]
# Out:
#         id                 livro         nome  sobrenome  \
# 138    139  A Tale of Two Cities       Daniel       Tran
# 192    193  A Tale of Two Cities      Richard   Phillips
# 447    448  A Tale of Two Cities        James       Cruz
# 494    495  A Tale of Two Cities        Julia      Moore
# 524    525  A Tale of Two Cities        Sonia   Williams
# 663    664  A Tale of Two Cities     Nicholas     Martin
# 1641  1642  A Tale of Two Cities         Kurt     French
# 1759  1760  A Tale of Two Cities  Christopher      Munoz
# 1921  1922  A Tale of Two Cities       Leslie  Patterson
# 2210  2211  A Tale of Two Cities        Kayla     Wright
# 2279  2280  A Tale of Two Cities      Colleen      White
# 2292  2293  A Tale of Two Cities         Anna      Lewis
# 2592  2593  A Tale of Two Cities       Dakota       Roth
# 2821  2822  A Tale of Two Cities    Elizabeth   Williams
# 2920  2921  A Tale of Two Cities        David     Clarke
# 3253  3254  A Tale of Two Cities        David     Reeves
# 3415  3416  A Tale of Two Cities         Kara    Estrada
# 3577  3578  A Tale of Two Cities       Olivia      Adams
# 4202  4203  A Tale of Two Cities        Brian    Swanson
# 4672  4673  A Tale of Two Cities         Judy      House
# 4737  4738  A Tale of Two Cities       Daniel     Morris
# 4829  4830  A Tale of Two Cities        Donna     Thomas
# 5242  5243  A Tale of Two Cities        Tracy    Jenkins
# 5251  5252  A Tale of Two Cities         Lori     Parker
# 5504  5505  A Tale of Two Cities        Devin      Lopez
# 5588  5589  A Tale of Two Cities         Mike     Carter
# 5638  5639  A Tale of Two Cities       Steven     Rivers
# 5717  5718  A Tale of Two Cities       Ashley    Perkins
# 5741  5742  A Tale of Two Cities      Chelsea     Duncan
# 5766  5767  A Tale of Two Cities         Mark   Castillo
# 5949  5950  A Tale of Two Cities         John     Peters
# 6240  6241  A Tale of Two Cities     Cheyenne       Reed
# 6255  6256  A Tale of Two Cities         Paul        Cox
# 6376  6377  A Tale of Two Cities        Tammy       King
# 6789  6790  A Tale of Two Cities       Joseph     Macias
# 6975  6976  A Tale of Two Cities       Tracey     Parker
# 7311  7312  A Tale of Two Cities        Dylan    Barnett
# 7747  7748  A Tale of Two Cities      Matthew    Chapman
# 8582  8583  A Tale of Two Cities     Fernando     Reeves
# 8772  8773  A Tale of Two Cities    Dominique   Williams
# 8910  8911  A Tale of Two Cities       Nicole      Davis
# 9120  9121  A Tale of Two Cities      Destiny  Armstrong
# 9309  9310  A Tale of Two Cities        David    Kennedy
# 9327  9328  A Tale of Two Cities       Sheila      White
# 9762  9763  A Tale of Two Cities         Sara    Simmons
# 9791  9792  A Tale of Two Cities      Ricardo  Hernandez
# 9968  9969  A Tale of Two Cities       Kaylee     Foster
#
#                                          comentario  id_livro
# 138   Um pouco lento no início, mas depois melhora.         0
# 192                       Simplesmente maravilhoso!         0
# 447   Um pouco lento no início, mas depois melhora.         0
# 494                      Um dos melhores que já li.         0
# 524                        Esperava mais do enredo.         0
# 663                        Esperava mais do enredo.         0
# 1641     Achei a história envolvente e bem escrita.         0
# 1759               Uma leitura incrível, recomendo!         0
# 1921             Boa leitura, mas não é meu estilo.         0
# 2210               Uma leitura incrível, recomendo!         0
# 2279     Achei a história envolvente e bem escrita.         0
# 2292                      Simplesmente maravilhoso!         0
# 2592  Um pouco lento no início, mas depois melhora.         0
# 2821                     Um dos melhores que já li.         0
# 2920                     Um dos melhores que já li.         0
# 3253     Achei a história envolvente e bem escrita.         0
# 3415                     Um dos melhores que já li.         0
# 3577  Um pouco lento no início, mas depois melhora.         0
# 4202  Um pouco lento no início, mas depois melhora.         0
# 4672               Uma leitura incrível, recomendo!         0
# 4737  Um pouco lento no início, mas depois melhora.         0
# 4829  Personagens cativantes e trama surpreendente.         0
# 5242              Li em um dia, não consegui parar!         0
# 5251                      Simplesmente maravilhoso!         0
# 5504             Boa leitura, mas não é meu estilo.         0
# 5588               Uma leitura incrível, recomendo!         0
# 5638                     Não gostei muito do final.         0
# 5717  Personagens cativantes e trama surpreendente.         0
# 5741                     Não gostei muito do final.         0
# 5766  Personagens cativantes e trama surpreendente.         0
# 5949              Li em um dia, não consegui parar!         0
# 6240     Achei a história envolvente e bem escrita.         0
# 6255              Li em um dia, não consegui parar!         0
# 6376                     Não gostei muito do final.         0
# 6789  Um pouco lento no início, mas depois melhora.         0
# 6975  Personagens cativantes e trama surpreendente.         0
# 7311                     Um dos melhores que já li.         0
# 7747     Achei a história envolvente e bem escrita.         0
# 8582                     Um dos melhores que já li.         0
# 8772     Achei a história envolvente e bem escrita.         0
# 8910                       Esperava mais do enredo.         0
# 9120     Achei a história envolvente e bem escrita.         0
# 9309  Personagens cativantes e trama surpreendente.         0
# 9327  Um pouco lento no início, mas depois melhora.         0
# 9762                      Simplesmente maravilhoso!         0
# 9791               Uma leitura incrível, recomendo!         0
# 9968  Um pouco lento no início, mas depois melhora.         0

# %%
df_comentarios['id_livro'] += 1
print(f"{df_comentarios['id_livro'].max()} {df_comentarios['id_livro'].min()}")
# Out:
# 174 1

# %%
# Substitui valores nulos por NULL e escapa aspas
def format_value(value):
    if pd.isna(value):
        return 'NULL'
    elif isinstance(value, str):
        value = value.replace("'", "''")  # Escapa aspas simples para SQL
        return f"'{value}'"
    else:
        return str(value)

# Nome do arquivo
output_file = "comentarios.sql"

# Abrir o arquivo e escrever os INSERTs
with open(output_file, 'w', encoding='utf-8') as f:
    for _, row in df_comentarios.iterrows():
        values = (
            format_value(row['id_livro']),
            format_value(row['nome']),
            format_value(row['sobrenome']),
            format_value(row['comentario'])
        )
        sql = f"INSERT INTO comentarios (livro_id, nome, sobrenome, comentario) VALUES ({', '.join(values)});\n"
        f.write(sql)

print(f"Arquivo '{output_file}' gerado com sucesso.")
# Out:
# Arquivo 'comentarios.sql' gerado com sucesso.
